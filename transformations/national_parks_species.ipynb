# %%
# importing Dependencies
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect
import pandas as pd

# %%
# Reading/importing csv file
# Printing csv file
species = "../Resources/National_Parks_Species.csv"
species_df = pd.read_csv(species, keep_default_na=False)
species_df.head()
# Out:
#   Species ID             Park Name Category         Order    Family  \
# 0  ACAD-1000  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 1  ACAD-1001  Acadia National Park   Mammal  Artiodactyla  Cervidae
# 2  ACAD-1002  Acadia National Park   Mammal     Carnivora   Canidae
# 3  ACAD-1003  Acadia National Park   Mammal     Carnivora   Canidae
# 4  ACAD-1004  Acadia National Park   Mammal     Carnivora   Canidae
#
#           Scientific Name                                       Common Names  \
# 0             Alces alces                                              Moose
# 1  Odocoileus virginianus  Northern White-Tailed Deer, Virginia Deer, Whi...
# 2           Canis latrans                             Coyote, Eastern Coyote
# 3             Canis lupus        Eastern Timber Wolf, Gray Wolf, Timber Wolf
# 4           Vulpes vulpes  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...
#
#   Record Status     Occurrence  Nativeness Abundance Seasonality  \
# 0      Approved        Present      Native      Rare    Resident
# 1      Approved        Present      Native  Abundant
# 2      Approved        Present  Not Native    Common
# 3      Approved  Not Confirmed      Native
# 4      Approved        Present     Unknown    Common     Breeder
#
#   Conservation Status Unnamed: 13
# 0
# 1
# 2  Species of Concern
# 3          Endangered
# 4

# %%
# Dropping unwanted columns
# Printing the new DataFrame
species_df = species_df.drop(columns=['Order', 'Family', 'Record Status', 'Nativeness', 'Seasonality', 'Conservation Status', 'Unnamed: 13'])
species_df.head()
# Out:
#   Species ID             Park Name Category         Scientific Name  \
# 0  ACAD-1000  Acadia National Park   Mammal             Alces alces
# 1  ACAD-1001  Acadia National Park   Mammal  Odocoileus virginianus
# 2  ACAD-1002  Acadia National Park   Mammal           Canis latrans
# 3  ACAD-1003  Acadia National Park   Mammal             Canis lupus
# 4  ACAD-1004  Acadia National Park   Mammal           Vulpes vulpes
#
#                                         Common Names     Occurrence Abundance
# 0                                              Moose        Present      Rare
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...        Present  Abundant
# 2                             Coyote, Eastern Coyote        Present    Common
# 3        Eastern Timber Wolf, Gray Wolf, Timber Wolf  Not Confirmed
# 4  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...        Present    Common

# %%
# Keeping species that are only "Present" - Keeping rows where value in "Occurrence" column is equal to "Present"
# Printing new DataFrame
species_df = species_df.loc[species_df['Occurrence'] == 'Present']
species_df.head()
# Out:
#   Species ID             Park Name Category         Scientific Name  \
# 0  ACAD-1000  Acadia National Park   Mammal             Alces alces
# 1  ACAD-1001  Acadia National Park   Mammal  Odocoileus virginianus
# 2  ACAD-1002  Acadia National Park   Mammal           Canis latrans
# 4  ACAD-1004  Acadia National Park   Mammal           Vulpes vulpes
# 8  ACAD-1008  Acadia National Park   Mammal        Lutra canadensis
#
#                                         Common Names Occurrence Abundance
# 0                                              Moose    Present      Rare
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...    Present  Abundant
# 2                             Coyote, Eastern Coyote    Present    Common
# 4  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...    Present    Common
# 8                                 Otter, River Otter    Present    Common

# %%
# Renaming columns
species_df = species_df.rename(columns={'Species ID': 'species_id', 'Park Name': 'park_name', 'Category': 'category', 'Scientific Name': 'scientific_name', 'Occurrence': 'occurrence', 'Common Names':'common_names', 'Occurence':'occurence', 'Abundance':'abundance'})
species_df.head()
# Out:
#   species_id             park_name category         scientific_name  \
# 0  ACAD-1000  Acadia National Park   Mammal             Alces alces
# 1  ACAD-1001  Acadia National Park   Mammal  Odocoileus virginianus
# 2  ACAD-1002  Acadia National Park   Mammal           Canis latrans
# 4  ACAD-1004  Acadia National Park   Mammal           Vulpes vulpes
# 8  ACAD-1008  Acadia National Park   Mammal        Lutra canadensis
#
#                                         common_names occurrence abundance
# 0                                              Moose    Present      Rare
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...    Present  Abundant
# 2                             Coyote, Eastern Coyote    Present    Common
# 4  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...    Present    Common
# 8                                 Otter, River Otter    Present    Common

# %%
# Checking for duplicates
# No duplicates
species_df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 4         False
# 8         False
#           ...
# 119243    False
# 119244    False
# 119245    False
# 119246    False
# 119247    False
# Length: 83278, dtype: bool

# %%
# Resetting index
# Printing new DataFrame
species_df = species_df.reset_index(drop=True)
species_df.head()
# Out:
#   species_id             park_name category         scientific_name  \
# 0  ACAD-1000  Acadia National Park   Mammal             Alces alces
# 1  ACAD-1001  Acadia National Park   Mammal  Odocoileus virginianus
# 2  ACAD-1002  Acadia National Park   Mammal           Canis latrans
# 3  ACAD-1004  Acadia National Park   Mammal           Vulpes vulpes
# 4  ACAD-1008  Acadia National Park   Mammal        Lutra canadensis
#
#                                         common_names occurrence abundance
# 0                                              Moose    Present      Rare
# 1  Northern White-Tailed Deer, Virginia Deer, Whi...    Present  Abundant
# 2                             Coyote, Eastern Coyote    Present    Common
# 3  Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...    Present    Common
# 4                                 Otter, River Otter    Present    Common

# %%
# Renaming the index to "id"
# Printing the new DataFrame
species_df.index.name = 'id'
species_df.head()
# Out:
#    species_id             park_name category         scientific_name  \
# id
# 0   ACAD-1000  Acadia National Park   Mammal             Alces alces
# 1   ACAD-1001  Acadia National Park   Mammal  Odocoileus virginianus
# 2   ACAD-1002  Acadia National Park   Mammal           Canis latrans
# 3   ACAD-1004  Acadia National Park   Mammal           Vulpes vulpes
# 4   ACAD-1008  Acadia National Park   Mammal        Lutra canadensis
#
#                                          common_names occurrence abundance
# id
# 0                                               Moose    Present      Rare
# 1   Northern White-Tailed Deer, Virginia Deer, Whi...    Present  Abundant
# 2                              Coyote, Eastern Coyote    Present    Common
# 3   Black Fox, Cross Fox, Eastern Red Fox, Fox, Re...    Present    Common
# 4                                  Otter, River Otter    Present    Common

# %%
# Creating database connection
connection_string = "postgres:postgres@localhost:5432/national_parks_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Loading DataFrame into database
species_df.to_sql(name='species', con=engine, if_exists='append', index=True)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UniqueViolation: duplicate key value violates unique constraint "pk_species"
# DETAIL:  Key (id)=(0) already exists.
#
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-21-38420869b10a> in <module>
#       1 # Loading DataFrame into database
# ----> 2 species_df.to_sql(name='species', con=engine, if_exists='append', index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# IntegrityError: (psycopg2.errors.UniqueViolation) duplicate key value violates unique constraint "pk_species"
# DETAIL:  Key (id)=(0) already exists.
#
# [SQL: INSERT INTO species (id, species_id, park_name, category, scientific_name, common_names, occurrence, abundance) VALUES (%(id)s, %(species_id)s, %(park_name)s, %(category)s, %(scientific_name)s, %(common_names)s, %(occurrence)s, %(abundance)s)]
# [parameters: ({'id': 0, 'species_id': 'ACAD-1000', 'park_name': 'Acadia National Park', 'category': 'Mammal', 'scientific_name': 'Alces alces', 'common_names': 'Moose', 'occurrence': 'Present', 'abundance': 'Rare'}, {'id': 1, 'species_id': 'ACAD-1001', 'park_name': 'Acadia National Park', 'category': 'Mammal', 'scientific_name': 'Odocoileus virginianus', 'common_names': 'Northern White-Tailed Deer, Virginia Deer, White-Tailed Deer', 'occurrence': 'Present', 'abundance': 'Abundant'}, {'id': 2, 'species_id': 'ACAD-1002', 'park_name': 'Acadia National Park', 'category': 'Mammal', 'scientific_name': 'Canis latrans', 'common_names': 'Coyote, Eastern Coyote', 'occurrence': 'Present', 'abundance': 'Common'}, {'id': 3, 'species_id': 'ACAD-1004', 'park_name': 'Acadia National Park', 'category': 'Mammal', 'scientific_name': 'Vulpes vulpes', 'common_names': 'Black Fox, Cross Fox, Eastern Red Fox, Fox, Red Fox, Silver Fox', 'occurrence': 'Present', 'abundance': 'Common'}, {'id': 4, 'species_id': 'ACAD-1008', 'park_name': 'Acadia National Park', 'category': 'Mammal', 'scientific_name': 'Lutra canadensis', 'common_names': 'Otter, River Otter', 'occurrence': 'Present', 'abundance': 'Common'}, {'id': 5, 'species_id': 'ACAD-1009', 'park_name': 'Acadia National Park', 'category': 'Mammal', 'scientific_name': 'Martes pennanti', 'common_names': 'Blackcat, Fisher, Pekan', 'occurrence': 'Present', 'abundance': 'Rare'}, {'id': 6, 'species_id': 'ACAD-1011', 'park_name': 'Acadia National Park', 'category': 'Mammal', 'scientific_name': 'Mustela erminea', 'common_names': "Bonaparte Weasel, Bonaparte's Weasel, Ermine, Short-Tailed Weasel", 'occurrence': 'Present', 'abundance': 'Uncommon'}, {'id': 7, 'species_id': 'ACAD-1012', 'park_name': 'Acadia National Park', 'category': 'Mammal', 'scientific_name': 'Mustela frenata', 'common_names': 'Long-Tailed Weasel, New York Weasel, Northern Long-Tailed Weasel', 'occurrence': 'Present', 'abundance': 'Uncommon'}  ... displaying 10 of 83278 total bound parameter sets ...  {'id': 83276, 'species_id': 'ZION-2794', 'park_name': 'Zion National Park', 'category': 'Vascular Plant', 'scientific_name': 'Larrea tridentata', 'common_names': 'Creosote Bush', 'occurrence': 'Present', 'abundance': 'Rare'}, {'id': 83277, 'species_id': 'ZION-2795', 'park_name': 'Zion National Park', 'category': 'Vascular Plant', 'scientific_name': 'Tribulus terrestris', 'common_names': 'Puncture Vine', 'occurrence': 'Present', 'abundance': 'Uncommon'})]
# (Background on this error at: http://sqlalche.me/e/13/gkpj)
